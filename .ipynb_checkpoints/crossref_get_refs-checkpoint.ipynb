# %%
# %load_ext autoreload
# %autoreload 2

from artfinder import Crossref, load_csv, strict_filter
from artfinder.helpers import full_texts_from_urls
import pandas as pd
import logging

logging.basicConfig(level=logging.INFO)
crosref = Crossref(app='artfinder', email='aapopov1@mephi.ru')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 get_ipython().run_line_magic('load_ext', 'autoreload')
#       2 get_ipython().run_line_magic('autoreload', '2')
# ----> 4 from artfinder import Crossref, load_csv, strict_filter
#       5 from artfinder.helpers import full_texts_from_urls
#       6 import pandas as pd
#
# File ~/dev/study/ablation_db/artfinder/__init__.py:1
# ----> 1 from .api import PubMed, Crossref, load_csv, strict_filter
#       2 from .article import PubMedArticle, CrossrefArticle
#       4 __all__ = ["PubMed", "PubMedArticle", "CrossrefArticle", "Crossref", "load_csv", "strict_filter"]
#
# File ~/dev/study/ablation_db/artfinder/api.py:18
#      15 import asyncio
#      16 import re
# ---> 18 import aiohttp
#      19 from aiohttp import ClientResponse, ClientSession
#      20 import requests
#
# ModuleNotFoundError: No module named 'aiohttp'

# %%
df = load_csv('database/processed/barcikowski_full.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548 entries, 0 to 547
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   publisher               548 non-null    string
#  1   license                 348 non-null    object
#  2   is_referenced_by_count  548 non-null    int64
#  3   link                    486 non-null    object
#  4   authors                 548 non-null    object
#  5   abstract                184 non-null    string
#  6   title                   548 non-null    string
#  7   doi                     548 non-null    string
#  8   type                    548 non-null    string
#  9   journal                 548 non-null    string
#  10  issn                    491 non-null    string
#  11  volume                  480 non-null    string
#  12  issue                   369 non-null    string
#  13  start_page              456 non-null    string
#  14  end_page                318 non-null    string
#  15  publication_date        548 non-null    datetime64[ns]
#  16  references              446 non-null    object
#  17  pmcid                   0 non-null      float64
#  18  pmid                    0 non-null      float64
#  19  keywords                0 non-null      float64
#  20  ablation                548 non-null    bool
# dtypes: bool(1), datetime64[ns](1), float64(3), int64(1), object(4), string(11)
# memory usage: 86.3+ KB

# %%
df = df.sort_values(by='publication_date', ascending=False).reset_index(drop=True)
df
# Out:
#                                              publisher  \
# 0                      american chemical society (acs)
# 1                                   beilstein institut
# 2                                          elsevier bv
# 3                                   beilstein institut
# 4    lukasiewicz research network - industrial chem...
# ..                                                 ...
# 543                                       s. karger ag
# 544  the nencki institute of experimental biology, ...
# 545  the kielanowski institute of animal physiology...
# 546                             georg thieme verlag kg
# 547                                        elsevier bv
#
#                                                license  \
# 0    [{'start': {'date-parts': [[2025, 3, 28]], 'da...
# 1    [{'start': {'date-parts': [[2025, 3, 25]], 'da...
# 2    [{'start': {'date-parts': [[2025, 3, 1]], 'dat...
# 3    [{'start': {'date-parts': [[2025, 2, 20]], 'da...
# 4    [{'start': {'date-parts': [[2025, 2, 19]], 'da...
# ..                                                 ...
# 543  [{'start': {'date-parts': [[1997, 1, 1]], 'dat...
# 544  [{'start': {'date-parts': [[1996, 9, 30]], 'da...
# 545                                               None
# 546                                               None
# 547  [{'start': {'date-parts': [[1993, 3, 1]], 'dat...
#
#      is_referenced_by_count  \
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0
# ..                      ...
# 543                      17
# 544                       3
# 545                      15
# 546                       2
# 547                       9
#
#                                                   link  \
# 0    [{'url': 'https://pubs.acs.org/doi/pdf/10.1021...
# 1    [{'url': 'https://www.beilstein-journals.org/b...
# 2    [{'url': 'https://api.elsevier.com/content/art...
# 3    [{'url': 'https://www.beilstein-journals.org/b...
# 4    [{'url': 'https://polimery.ichp.vot.pl/index.p...
# ..                                                 ...
# 543  [{'url': 'https://www.karger.com/article/pdf/1...
# 544  [{'url': 'https://ane.pl/index.php/ane/article...
# 545  [{'url': 'http://www.journalssystem.com/jafs/p...
# 546  [{'url': 'http://www.thieme-connect.de/product...
# 547  [{'url': 'https://api.elsevier.com/content/art...
#
#                                                authors  \
# 0    [{'lastname': 'friedenauer', 'firstname': 'tin...
# 1    [{'lastname': 'altakroury', 'firstname': 'abde...
# 2    [{'lastname': 'gabriel', 'firstname': 'philipp...
# 3    [{'lastname': 'fromme', 'firstname': 'theo', '...
# 4    [{'lastname': 'paczkowska', 'firstname': 'karo...
# ..                                                 ...
# 543  [{'lastname': 'misztal', 'firstname': 'tomasz'...
# 544  [{'lastname': 'misztal', 'firstname': 'tomasz'...
# 545  [{'lastname': 'misztal', 'firstname': 't.', 'a...
# 546  [{'lastname': 'galikowski', 'firstname': 'm.',...
# 547  [{'lastname': 'ziecik', 'firstname': 'a.j.', '...
#
#                                               abstract  \
# 0                                                 <NA>
# 1    the potential to modify the size distribution ...
# 2                                                 <NA>
# 3    pulsed laser ablation in liquids (lal) is an e...
# 4    the residual torsional strength of composite p...
# ..                                                 ...
# 543                                               <NA>
# 544  secretion of all the pituitary hormones underg...
# 545                                               <NA>
# 546                                               <NA>
# 547                                               <NA>
#
#                                                  title  \
# 0    on the mechanism and productivity of single-pu...
# 1    size control of nanoparticles synthesized by p...
# 2    surface modification of nd-fe-b feedstocks by ...
# 3    preferential enrichment and extraction of lase...
# 4    post-impact residual torsional strength and ac...
# ..                                                 ...
# 543  natural and melatonin-stimulated changes in th...
# 544  effects of melatonin infused into the iii vent...
# 545  seasonal changes of melatonin secretion
# in rel...
# 546  video-assisted thoracoscopy for closure of a b...
# 547  effect of human chorionic gonadotropin on myom...
#
#                                doi             type  \
# 0         10.1021/acs.jpcc.4c08643  journal-article
# 1             10.3762/bjnano.16.31  journal-article
# 2    10.1016/j.jallcom.2025.179308  journal-article
# 3             10.3762/bjnano.16.20  journal-article
# 4       10.14314/polimery.2025.1.4  journal-article
# ..                             ...              ...
# 543              10.1159/000127259  journal-article
# 544         10.55782/ane-1996-1182  journal-article
# 545       10.22358/jafs/69583/1996  journal-article
# 546         10.1055/s-2007-1013771  journal-article
# 547   10.1016/0378-4320(93)90033-n  journal-article
#
#                                      journal  ... volume issue start_page  \
# 0        the journal of physical chemistry c  ...   <NA>  <NA>       <NA>
# 1        beilstein journal of nanotechnology  ...     16  <NA>        407
# 2            journal of alloys and compounds  ...   1020  <NA>     179308
# 3        beilstein journal of nanotechnology  ...     16  <NA>        254
# 4                                   polimery  ...     70     1         30
# ..                                       ...  ...    ...   ...        ...
# 543                       neuroendocrinology  ...     66     5        360
# 544       acta neurobiologiae experimentalis  ...     56     3        769
# 545      journal of animal and feed sciences  ...      5     1         35
# 546  the thoracic and cardiovascular surgeon  ...     43    01         60
# 547              animal reproduction science  ...     31   1-2        131
#
#     end_page publication_date  \
# 0       <NA>       2025-03-28
# 1        417       2025-03-25
# 2       <NA>       2025-03-01
# 3        263       2025-02-20
# 4         39       2025-02-19
# ..       ...              ...
# 543      367       1997-01-01
# 544      778       1996-09-30
# 545       48       1996-01-12
# 546       61       1995-02-01
# 547      139       1993-03-01
#
#                                             references pmcid  pmid  keywords  \
# 0    [10.1021/acs.jpcc.8b04374, 10.1002/cphc.202200...   NaN   NaN       NaN
# 1    [10.1016/j.bios.2015.05.073, 10.1016/j.colsurf...   NaN   NaN       NaN
# 2    [10.1179/174328008x309690, 10.1007/bf03339106,...   NaN   NaN       NaN
# 3    [10.1021/acs.chemrev.6b00468, 10.1016/j.jcis.2...   NaN   NaN       NaN
# 4    [10.3390/polym12061288, 10.59324/ejaset.2024.2...   NaN   NaN       NaN
# ..                                                 ...   ...   ...       ...
# 543                                               None   NaN   NaN       NaN
# 544                                               None   NaN   NaN       NaN
# 545                                               None   NaN   NaN       NaN
# 546                                               None   NaN   NaN       NaN
# 547  [10.1095/biolreprod40.3.511, 10.1210/endo-126-...   NaN   NaN       NaN
#
#      ablation
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False
# ..        ...
# 543     False
# 544     False
# 545     False
# 546     False
# 547     False
#
# [548 rows x 21 columns]

# %%
def get_pdf_link(link_entry: list[dict]|None) -> str|None:
    """
    Extracts the PDF link from the provided link entry."
    """

    if link_entry is None or len(link_entry) == 0:
        return None
    for entry in link_entry:
        if entry.get('content-type') == 'application/pdf':
            return entry.get('url')

# %%
df['full_text_link'] = df['link'].map(get_pdf_link)
full_text_links = df['full_text_link'].dropna()

# %%
urls = full_text_links.iloc[2:7].to_list()

# %%
full_texts_from_urls(urls)
# Out:
# Downloaded 3/5 files
# Task 0: Failed to download file. HTTP status: 403
# Task 1: Downloading: 0.00% (9315.8/0.0 kb)
# Task 2: File downloaded: download/file_2.pdf
# Task 3: File downloaded: download/file_3.pdf
# Task 4: Failed to download file. HTTP status: 403

# %% [markdown]
# filer link by .pdf

# %%
full_text_links.to_csv('full_text_links.csv', index=False)
