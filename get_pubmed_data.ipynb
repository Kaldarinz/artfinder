# %% [markdown]
# # Formation of articles list which present results of pulsed laser-ablative synthesis of nanoparticles
#
# Articles are searched in PubMed database.
# Articles are searched in 3 steps:
# 1. Initial (base) list of consists of articles where:
#    1. Author list includes Kabashin or Barcikowski;
#    2. keywords include "pulsed laser ablation in liquids" or "laser ablation in liquids" or "laser fragmentation in liquids" or ("nanoparticles" and "laser ablation");
#    3. Articles are published after 1992.
# 2. Obtained articles, which cite articles from base list
# 3. Obtained articles, which are cited in base list

# %%
import logging
from typing import  Iterable

import pandas as pd

from artfinder import PubMedArticle, PubMed

#logging.basicConfig(level=logging.DEBUG,datefmt='%H:%M:%S' , format='%(asctime)s.%(msecs)03d - %(module)s/%(funcName)s:%(lineno)d - %(levelname)s - %(message)s')
logging.basicConfig(level=logging.INFO,datefmt='%H:%M:%S' , format='%(asctime)s.%(msecs)03d - %(module)s/%(funcName)s:%(lineno)d - %(levelname)s - %(message)s')

pubmed = PubMed()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       2 from typing import  Iterable
#       4 import pandas as pd
# ----> 6 from pymedx_custom import PubMedArticle, PubMed
#       8 #logging.basicConfig(level=logging.DEBUG,datefmt='%H:%M:%S' , format='%(asctime)s.%(msecs)03d - %(module)s/%(funcName)s:%(lineno)d - %(levelname)s - %(message)s')
#       9 logging.basicConfig(level=logging.INFO,datefmt='%H:%M:%S' , format='%(asctime)s.%(msecs)03d - %(module)s/%(funcName)s:%(lineno)d - %(levelname)s - %(message)s')
#
# File ~/dev/study/ablation_db/pymedx_custom/__init__.py:1
# ----> 1 from .api import PubMed
#       2 from .article import PubMedArticle, CrossrefArticle
#       4 __all__ = ["PubMed", "PubMedArticle", "CrossrefArticle"]
#
# File ~/dev/study/ablation_db/pymedx_custom/api.py:18
#      15 from lxml import etree as xml
#      16 from typeguard import typechecked
# ---> 18 from pymedx_custom.article import PubMedArticle
#      19 from pymedx_custom.book import PubMedBookArticle
#      20 from pymedx_custom.helpers import (
#      21     arrange_query,
#      22     batches,
#    (...)     27     pretty_print_xml
#      28 )
#
# File ~/dev/study/ablation_db/pymedx_custom/article.py:214
#     198         """Dump the object as JSON string."""
#     199         return json.dumps(
#     200             {
#     201                 key: (
#    (...)    209             indent=4,
#     210         )
#     213 @typechecked
# --> 214 class CrossrefArticle(Article):
#     215     """Data class that contains a Crossref article."""
#     217     __slots__ = (
#     218         "author",
#     219         "publisher",
#    (...)    234         "abstract",
#     235     )
#
# TypeError: __slots__ must be identifiers

# %% [markdown]
# Helper functions

# %%
def get_df(articles: Iterable[PubMedArticle]) -> pd.DataFrame:
    "Construct a DataFrame from a list of PubMedArticle objects"
    
    dict_articles = [x.to_dict() for x in articles]
    print(f"Total articles: {len(dict_articles)}")
    return pd.DataFrame(dict_articles)

# %% [markdown]
# ## Step 1
# Base list of articles is a set of articles where:
#  - Author: Kabashin
#  - or Author: Barcikowski
#  - or Keywords: "pulsed laser ablation in liquids"
#  - or Keywords: "laser ablation in liquids"
#  - or Keywords: "nanoparticles" AND "laser ablation"
#  - or Keywords: "laser fragmentation in liquids"
#  - Articles are published after 1992

# %%
print(author:= "Kabashin[AU]")
base = get_df(pubmed.query(author))

print(author:="Barcikowski[AU]")
base = pd.concat([base, get_df(pubmed.query(author))])

print(keywords:="pulsed laser ablation in liquids[OT]")
base = pd.concat([base, get_df(pubmed.query(keywords))])

print(keywords:= "pulsed laser ablation in liquid[OT]")
base = pd.concat([base, get_df(pubmed.query(keywords))])

print(keywords:= "laser ablation in liquids[OT]")
base = pd.concat([base, get_df(pubmed.query(keywords))])

print(keywords:= "laser ablation in liquid[OT]")
base = pd.concat([base, get_df(pubmed.query(keywords))])

print(keywords:= "laser ablation[OT] AND nanoparticles[OT]")
base = pd.concat([base, get_df(pubmed.query(keywords))])

print(keywords:= "ablation[OT] AND nanoparticles[OT]")
base = pd.concat([base, get_df(pubmed.query(keywords))])

print(keywords:= "fragmentation[OT] AND nanoparticles[OT]")
base = pd.concat([base, get_df(pubmed.query(keywords))])

print(keywords:= "laser fragmentation in liquids[OT]")
base = pd.concat([base, get_df(pubmed.query(keywords))])

print(keywords:= "laser fragmentation in liquid[OT]")
base = pd.concat([base, get_df(pubmed.query(keywords))])

print(keywords:= "plal[OT]")
base = pd.concat([base, get_df(pubmed.query(keywords))])

# Drop duplicates
base.drop_duplicates(subset='doi', inplace=True)

# Drop too old
base = base[base['publication_date'] > '1993-01-01']
# Out:
# Kabashin[AU]
# 17:33:02.645 - api/query:97 - INFO - Found: 82 articles. Fetching...
# Total articles: 82
# Barcikowski[AU]
# 17:33:09.010 - api/query:97 - INFO - Found: 272 articles. Fetching...
# 17:33:14.957 - api/_getArticles:397 - INFO - Unrecognized articles: 1
# Total articles: 271
# pulsed laser ablation in liquids[OT]
# 17:33:17.410 - api/query:97 - INFO - Found: 24 articles. Fetching...
# Total articles: 24
# pulsed laser ablation in liquid[OT]
# 17:33:21.783 - api/query:97 - INFO - Found: 18 articles. Fetching...
# Total articles: 18
# laser ablation in liquids[OT]
# 17:33:25.497 - api/query:97 - INFO - Found: 54 articles. Fetching...
# Total articles: 54
# laser ablation in liquid[OT]
# 17:33:31.107 - api/query:97 - INFO - Found: 63 articles. Fetching...
# Total articles: 63
# laser ablation[OT] AND nanoparticles[OT]
# 17:33:38.531 - api/query:97 - INFO - Found: 215 articles. Fetching...
# Total articles: 215
# ablation[OT] AND nanoparticles[OT]
# 17:33:48.043 - api/query:97 - INFO - Found: 312 articles. Fetching...
# Total articles: 312
# fragmentation[OT] AND nanoparticles[OT]
# 17:34:01.305 - api/query:97 - INFO - Found: 68 articles. Fetching...
# Total articles: 68
# laser fragmentation in liquids[OT]
# 17:34:06.904 - api/query:97 - INFO - Found: 4 articles. Fetching...
# Total articles: 4
# laser fragmentation in liquid[OT]
# 17:34:10.369 - api/query:97 - INFO - Found: 4 articles. Fetching...
# Total articles: 4
# plal[OT]
# 17:34:13.815 - api/query:97 - INFO - Found: 18 articles. Fetching...
# Total articles: 18
# lal[OT]
# 17:34:17.329 - api/query:97 - INFO - Found: 153 articles. Fetching...
# 17:34:21.630 - api/_getArticles:397 - INFO - Unrecognized articles: 1
# Total articles: 152

# %% [markdown]
# ## Step 2
# Get list of articles, which cite articles from base list

# %%
citing = pd.DataFrame(columns=base.columns)

tot_articles = len(base)
for i, pmid in enumerate(base['pmid']):
    logging.info(f'Start fetching article {i+1}/{tot_articles} - {pmid}')
    articles = pubmed.getCitingArticles(pmid)
    dict_articles = [x.to_dict() for x in articles]
    citing = pd.concat([citing, pd.DataFrame(dict_articles)], ignore_index=True)

# Drop duplicates
citing.drop_duplicates(subset='doi', inplace=True)

# Drop articles from base list
citing = citing[~citing.doi.isin(base.doi)]
# Out:
# 18:09:04.967 - 1858469794/<module>:5 - INFO - Start fetching article 1/812 - 39791764
# 18:09:06.390 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:09:06.391 - 1858469794/<module>:5 - INFO - Start fetching article 2/812 - 39683349
# 18:09:07.377 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:09:07.378 - 1858469794/<module>:5 - INFO - Start fetching article 3/812 - 39253754
# 18:09:08.459 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:09:08.460 - 1858469794/<module>:5 - INFO - Start fetching article 4/812 - 39203014
# 18:09:09.376 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:09:09.377 - 1858469794/<module>:5 - INFO - Start fetching article 5/812 - 38795244
# 18:09:10.606 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:09:10.609 - 1858469794/<module>:5 - INFO - Start fetching article 6/812 - 38739779
# 18:09:11.630 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:09:11.633 - 1858469794/<module>:5 - INFO - Start fetching article 7/812 - 38730109
# 18:09:12.667 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:09:12.668 - 1858469794/<module>:5 - INFO - Start fetching article 8/812 - 38516744
# 18:09:13.564 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# /tmp/ipykernel_23849/1858469794.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   citing = pd.concat([citing, pd.DataFrame(dict_articles)], ignore_index=True)
# 18:09:14.527 - 1858469794/<module>:5 - INFO - Start fetching article 9/812 - 38491259
# 18:09:15.497 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:09:15.498 - 1858469794/<module>:5 - INFO - Start fetching article 10/812 - 38260353
# 18:09:18.232 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:09:18.233 - 1858469794/<module>:5 - INFO - Start fetching article 11/812 - 38069412
# 18:09:19.177 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:09:20.329 - 1858469794/<module>:5 - INFO - Start fetching article 12/812 - 37963406
# 18:09:21.937 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:09:21.938 - 1858469794/<module>:5 - INFO - Start fetching article 13/812 - 37738093
# 18:09:23.521 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:09:25.582 - 1858469794/<module>:5 - INFO - Start fetching article 14/812 - 37681251
# 18:09:26.598 - api/getCitingArticles:130 - INFO - Found: 6 siting articles. Fetching...
# 18:09:28.780 - 1858469794/<module>:5 - INFO - Start fetching article 15/812 - 37570573
# 18:09:29.694 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:09:31.307 - 1858469794/<module>:5 - INFO - Start fetching article 16/812 - 37570485
# 18:09:32.416 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:09:33.814 - 1858469794/<module>:5 - INFO - Start fetching article 17/812 - 37111532
# 18:09:34.660 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:09:36.225 - 1858469794/<module>:5 - INFO - Start fetching article 18/812 - 36122203
# 18:09:37.173 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:09:38.476 - 1858469794/<module>:5 - INFO - Start fetching article 19/812 - 35955245
# 18:09:39.458 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:09:40.519 - 1858469794/<module>:5 - INFO - Start fetching article 20/812 - 35839934
# 18:09:41.461 - api/getCitingArticles:130 - INFO - Found: 5 siting articles. Fetching...
# 18:09:43.127 - 1858469794/<module>:5 - INFO - Start fetching article 21/812 - 35650237
# 18:09:44.023 - api/getCitingArticles:130 - INFO - Found: 7 siting articles. Fetching...
# 18:09:45.884 - 1858469794/<module>:5 - INFO - Start fetching article 22/812 - 35631580
# 18:09:46.828 - api/getCitingArticles:130 - INFO - Found: 6 siting articles. Fetching...
# 18:09:48.744 - 1858469794/<module>:5 - INFO - Start fetching article 23/812 - 35630892
# 18:09:49.859 - api/getCitingArticles:130 - INFO - Found: 6 siting articles. Fetching...
# 18:09:51.457 - 1858469794/<module>:5 - INFO - Start fetching article 24/812 - 35294165
# 18:09:52.588 - api/getCitingArticles:130 - INFO - Found: 20 siting articles. Fetching...
# 18:09:56.164 - 1858469794/<module>:5 - INFO - Start fetching article 25/812 - 35214980
# 18:09:57.094 - api/getCitingArticles:130 - INFO - Found: 7 siting articles. Fetching...
# 18:09:58.767 - 1858469794/<module>:5 - INFO - Start fetching article 26/812 - 35190528
# 18:09:59.961 - api/getCitingArticles:130 - INFO - Found: 14 siting articles. Fetching...
# 18:10:02.272 - 1858469794/<module>:5 - INFO - Start fetching article 27/812 - 33670727
# 18:10:04.263 - api/getCitingArticles:130 - INFO - Found: 5 siting articles. Fetching...
# 18:10:06.155 - 1858469794/<module>:5 - INFO - Start fetching article 28/812 - 33652885
# 18:10:07.198 - api/getCitingArticles:130 - INFO - Found: 10 siting articles. Fetching...
# 18:10:09.502 - 1858469794/<module>:5 - INFO - Start fetching article 29/812 - 33545869
# 18:10:10.493 - api/getCitingArticles:130 - INFO - Found: 18 siting articles. Fetching...
# 18:10:13.387 - 1858469794/<module>:5 - INFO - Start fetching article 30/812 - 33325873
# 18:10:14.557 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:10:15.666 - 1858469794/<module>:5 - INFO - Start fetching article 31/812 - 32935975
# 18:10:16.659 - api/getCitingArticles:130 - INFO - Found: 22 siting articles. Fetching...
# 18:10:21.295 - 1858469794/<module>:5 - INFO - Start fetching article 32/812 - 32722581
# 18:10:22.259 - api/getCitingArticles:130 - INFO - Found: 8 siting articles. Fetching...
# 18:10:23.826 - 1858469794/<module>:5 - INFO - Start fetching article 33/812 - 32013147
# 18:10:24.930 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:10:26.438 - 1858469794/<module>:5 - INFO - Start fetching article 34/812 - 31973084
# 18:10:27.350 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:10:28.700 - 1858469794/<module>:5 - INFO - Start fetching article 35/812 - 31905619
# 18:10:29.576 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:10:30.760 - 1858469794/<module>:5 - INFO - Start fetching article 36/812 - 31878215
# 18:10:31.636 - api/getCitingArticles:130 - INFO - Found: 5 siting articles. Fetching...
# 18:10:33.025 - 1858469794/<module>:5 - INFO - Start fetching article 37/812 - 31501470
# 18:10:34.995 - api/getCitingArticles:130 - INFO - Found: 77 siting articles. Fetching...
# 18:10:40.946 - 1858469794/<module>:5 - INFO - Start fetching article 38/812 - 31490658
# 18:10:41.955 - api/getCitingArticles:130 - INFO - Found: 23 siting articles. Fetching...
# 18:10:45.941 - 1858469794/<module>:5 - INFO - Start fetching article 39/812 - 31344823
# 18:10:46.880 - api/getCitingArticles:130 - INFO - Found: 8 siting articles. Fetching...
# 18:10:48.569 - 1858469794/<module>:5 - INFO - Start fetching article 40/812 - 30765778
# 18:10:49.633 - api/getCitingArticles:130 - INFO - Found: 13 siting articles. Fetching...
# 18:10:51.953 - 1858469794/<module>:5 - INFO - Start fetching article 41/812 - 30718560
# 18:10:52.844 - api/getCitingArticles:130 - INFO - Found: 26 siting articles. Fetching...
# 18:10:58.238 - 1858469794/<module>:5 - INFO - Start fetching article 42/812 - 29863344
# 18:10:59.565 - api/getCitingArticles:130 - INFO - Found: 142 siting articles. Fetching...
# 18:11:05.068 - 1858469794/<module>:5 - INFO - Start fetching article 43/812 - 29794976
# 18:11:06.195 - api/getCitingArticles:130 - INFO - Found: 11 siting articles. Fetching...
# 18:11:08.927 - 1858469794/<module>:5 - INFO - Start fetching article 44/812 - 29388744
# 18:11:10.420 - api/getCitingArticles:130 - INFO - Found: 22 siting articles. Fetching...
# 18:11:12.799 - 1858469794/<module>:5 - INFO - Start fetching article 45/812 - 29331424
# 18:11:14.013 - api/getCitingArticles:130 - INFO - Found: 23 siting articles. Fetching...
# 18:11:16.930 - 1858469794/<module>:5 - INFO - Start fetching article 46/812 - 29029737
# 18:11:17.842 - api/getCitingArticles:130 - INFO - Found: 16 siting articles. Fetching...
# 18:11:20.357 - 1858469794/<module>:5 - INFO - Start fetching article 47/812 - 28240811
# 18:11:21.254 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:11:22.698 - 1858469794/<module>:5 - INFO - Start fetching article 48/812 - 32263775
# 18:11:23.725 - api/getCitingArticles:130 - INFO - Found: 18 siting articles. Fetching...
# 18:11:25.913 - 1858469794/<module>:5 - INFO - Start fetching article 49/812 - 27527580
# 18:11:26.860 - api/getCitingArticles:130 - INFO - Found: 14 siting articles. Fetching...
# 18:11:28.920 - 1858469794/<module>:5 - INFO - Start fetching article 50/812 - 27151839
# 18:11:30.077 - api/getCitingArticles:130 - INFO - Found: 30 siting articles. Fetching...
# 18:11:34.290 - 1858469794/<module>:5 - INFO - Start fetching article 51/812 - 27151104
# 18:11:35.347 - api/getCitingArticles:130 - INFO - Found: 16 siting articles. Fetching...
# 18:11:39.228 - 1858469794/<module>:5 - INFO - Start fetching article 52/812 - 27102695
# 18:11:40.158 - api/getCitingArticles:130 - INFO - Found: 19 siting articles. Fetching...
# 18:11:42.300 - 1858469794/<module>:5 - INFO - Start fetching article 53/812 - 26878568
# 18:11:43.251 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:11:44.634 - 1858469794/<module>:5 - INFO - Start fetching article 54/812 - 26349431
# 18:11:45.588 - api/getCitingArticles:130 - INFO - Found: 58 siting articles. Fetching...
# 18:11:49.224 - 1858469794/<module>:5 - INFO - Start fetching article 55/812 - 25605000
# 18:11:50.291 - api/getCitingArticles:130 - INFO - Found: 18 siting articles. Fetching...
# 18:11:52.130 - 1858469794/<module>:5 - INFO - Start fetching article 56/812 - 25473280
# 18:11:53.037 - api/getCitingArticles:130 - INFO - Found: 34 siting articles. Fetching...
# 18:11:56.374 - 1858469794/<module>:5 - INFO - Start fetching article 57/812 - 25391603
# 18:11:57.352 - api/getCitingArticles:130 - INFO - Found: 45 siting articles. Fetching...
# 18:12:02.535 - 1858469794/<module>:5 - INFO - Start fetching article 58/812 - 24642787
# 18:12:03.682 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:12:04.932 - 1858469794/<module>:5 - INFO - Start fetching article 59/812 - 23888114
# 18:12:05.801 - api/getCitingArticles:130 - INFO - Found: 5 siting articles. Fetching...
# 18:12:07.933 - 1858469794/<module>:5 - INFO - Start fetching article 60/812 - 32261049
# 18:12:08.781 - api/getCitingArticles:130 - INFO - Found: 12 siting articles. Fetching...
# 18:12:11.234 - 1858469794/<module>:5 - INFO - Start fetching article 61/812 - 23314104
# 18:12:12.367 - api/getCitingArticles:130 - INFO - Found: 67 siting articles. Fetching...
# 18:12:15.638 - 1858469794/<module>:5 - INFO - Start fetching article 62/812 - 23262740
# 18:12:16.669 - api/getCitingArticles:130 - INFO - Found: 12 siting articles. Fetching...
# 18:12:18.352 - 1858469794/<module>:5 - INFO - Start fetching article 63/812 - 20672069
# 18:12:19.302 - api/getCitingArticles:130 - INFO - Found: 26 siting articles. Fetching...
# 18:12:22.745 - 1858469794/<module>:5 - INFO - Start fetching article 64/812 - 20639919
# 18:12:23.747 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:12:25.143 - 1858469794/<module>:5 - INFO - Start fetching article 65/812 - 20364182
# 18:12:26.056 - api/getCitingArticles:130 - INFO - Found: 17 siting articles. Fetching...
# 18:12:28.533 - 1858469794/<module>:5 - INFO - Start fetching article 66/812 - 19997358
# 18:12:29.671 - api/getCitingArticles:130 - INFO - Found: 37 siting articles. Fetching...
# 18:12:32.139 - 1858469794/<module>:5 - INFO - Start fetching article 67/812 - 19997319
# 18:12:33.358 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:12:34.732 - 1858469794/<module>:5 - INFO - Start fetching article 68/812 - 19820701
# 18:12:35.822 - api/getCitingArticles:130 - INFO - Found: 188 siting articles. Fetching...
# 18:12:44.283 - 1858469794/<module>:5 - INFO - Start fetching article 69/812 - 19405723
# 18:12:45.230 - api/getCitingArticles:130 - INFO - Found: 12 siting articles. Fetching...
# 18:12:46.941 - 1858469794/<module>:5 - INFO - Start fetching article 70/812 - 19219129
# 18:12:48.922 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:12:50.011 - 1858469794/<module>:5 - INFO - Start fetching article 71/812 - 19104560
# 18:12:51.326 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:12:51.330 - 1858469794/<module>:5 - INFO - Start fetching article 72/812 - 19547622
# 18:12:52.436 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:12:53.478 - 1858469794/<module>:5 - INFO - Start fetching article 73/812 - 17804214
# 18:12:54.611 - api/getCitingArticles:130 - INFO - Found: 7 siting articles. Fetching...
# 18:12:56.759 - 1858469794/<module>:5 - INFO - Start fetching article 74/812 - 19547499
# 18:12:57.766 - api/getCitingArticles:130 - INFO - Found: 13 siting articles. Fetching...
# 18:13:00.072 - 1858469794/<module>:5 - INFO - Start fetching article 75/812 - 19547372
# 18:13:01.410 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:13:01.414 - 1858469794/<module>:5 - INFO - Start fetching article 76/812 - 19532412
# 18:13:02.456 - api/getCitingArticles:130 - INFO - Found: 9 siting articles. Fetching...
# 18:13:04.661 - 1858469794/<module>:5 - INFO - Start fetching article 77/812 - 19529219
# 18:13:05.597 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:13:06.906 - 1858469794/<module>:5 - INFO - Start fetching article 78/812 - 16912808
# 18:13:07.984 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:13:09.223 - 1858469794/<module>:5 - INFO - Start fetching article 79/812 - 15186145
# 18:13:10.118 - api/getCitingArticles:130 - INFO - Found: 26 siting articles. Fetching...
# 18:13:13.745 - 1858469794/<module>:5 - INFO - Start fetching article 80/812 - 14661802
# 18:13:14.687 - api/getCitingArticles:130 - INFO - Found: 5 siting articles. Fetching...
# 18:13:16.190 - 1858469794/<module>:5 - INFO - Start fetching article 81/812 - 12938922
# 18:13:17.366 - api/getCitingArticles:130 - INFO - Found: 5 siting articles. Fetching...
# 18:13:19.473 - 1858469794/<module>:5 - INFO - Start fetching article 82/812 - 9883560
# 18:13:20.462 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:13:22.346 - 1858469794/<module>:5 - INFO - Start fetching article 83/812 - 39995759
# 18:13:23.535 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:13:23.538 - 1858469794/<module>:5 - INFO - Start fetching article 84/812 - 39913862
# 18:13:24.764 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:13:24.767 - 1858469794/<module>:5 - INFO - Start fetching article 85/812 - 39435622
# 18:13:25.625 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:13:25.629 - 1858469794/<module>:5 - INFO - Start fetching article 86/812 - 39381778
# 18:13:27.027 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:13:27.030 - 1858469794/<module>:5 - INFO - Start fetching article 87/812 - 39143861
# 18:13:27.950 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:13:27.953 - 1858469794/<module>:5 - INFO - Start fetching article 88/812 - 39121414
# 18:13:29.072 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:13:29.076 - 1858469794/<module>:5 - INFO - Start fetching article 89/812 - 38887526
# 18:13:30.087 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:13:31.749 - 1858469794/<module>:5 - INFO - Start fetching article 90/812 - 38842467
# 18:13:32.716 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:13:32.719 - 1858469794/<module>:5 - INFO - Start fetching article 91/812 - 38336925
# 18:13:33.630 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:13:35.345 - 1858469794/<module>:5 - INFO - Start fetching article 92/812 - 38221893
# 18:13:36.490 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:13:36.493 - 1858469794/<module>:5 - INFO - Start fetching article 93/812 - 37699973
# 18:13:37.438 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:13:38.673 - 1858469794/<module>:5 - INFO - Start fetching article 94/812 - 37661312
# 18:13:39.615 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:13:41.738 - 1858469794/<module>:5 - INFO - Start fetching article 95/812 - 37334753
# 18:13:42.744 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:13:42.746 - 1858469794/<module>:5 - INFO - Start fetching article 96/812 - 36878868
# 18:13:43.711 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:13:45.499 - 1858469794/<module>:5 - INFO - Start fetching article 97/812 - 36650990
# 18:13:46.882 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:13:47.982 - 1858469794/<module>:5 - INFO - Start fetching article 98/812 - 36625361
# 18:13:48.841 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:13:48.844 - 1858469794/<module>:5 - INFO - Start fetching article 99/812 - 36562550
# 18:13:49.772 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:13:49.776 - 1858469794/<module>:5 - INFO - Start fetching article 100/812 - 36562474
# 18:13:50.827 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:13:51.970 - 1858469794/<module>:5 - INFO - Start fetching article 101/812 - 36562328
# 18:13:54.077 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:13:55.300 - 1858469794/<module>:5 - INFO - Start fetching article 102/812 - 36546553
# 18:13:56.472 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:13:56.476 - 1858469794/<module>:5 - INFO - Start fetching article 103/812 - 36282676
# 18:13:57.326 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:13:58.538 - 1858469794/<module>:5 - INFO - Start fetching article 104/812 - 36260482
# 18:13:59.683 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:13:59.686 - 1858469794/<module>:5 - INFO - Start fetching article 105/812 - 36222171
# 18:14:00.680 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:14:03.475 - 1858469794/<module>:5 - INFO - Start fetching article 106/812 - 36148583
# 18:14:04.507 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:14:05.881 - 1858469794/<module>:5 - INFO - Start fetching article 107/812 - 36008988
# 18:14:07.134 - api/getCitingArticles:130 - INFO - Found: 11 siting articles. Fetching...
# 18:14:09.051 - 1858469794/<module>:5 - INFO - Start fetching article 108/812 - 35911453
# 18:14:10.062 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:14:11.587 - 1858469794/<module>:5 - INFO - Start fetching article 109/812 - 35830817
# 18:14:12.475 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:14:13.979 - 1858469794/<module>:5 - INFO - Start fetching article 110/812 - 35637878
# 18:14:14.912 - api/getCitingArticles:130 - INFO - Found: 6 siting articles. Fetching...
# 18:14:16.795 - 1858469794/<module>:5 - INFO - Start fetching article 111/812 - 35437923
# 18:14:17.683 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:14:17.685 - 1858469794/<module>:5 - INFO - Start fetching article 112/812 - 35396555
# 18:14:18.598 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:14:19.854 - 1858469794/<module>:5 - INFO - Start fetching article 113/812 - 35380738
# 18:14:20.744 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:14:21.725 - 1858469794/<module>:5 - INFO - Start fetching article 114/812 - 35322802
# 18:14:22.680 - api/getCitingArticles:130 - INFO - Found: 7 siting articles. Fetching...
# 18:14:24.279 - 1858469794/<module>:5 - INFO - Start fetching article 115/812 - 34921500
# 18:14:25.998 - api/getCitingArticles:130 - INFO - Found: 8 siting articles. Fetching...
# 18:14:28.609 - 1858469794/<module>:5 - INFO - Start fetching article 116/812 - 34829358
# 18:14:29.704 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:14:31.189 - 1858469794/<module>:5 - INFO - Start fetching article 117/812 - 34730343
# 18:14:32.206 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:14:33.922 - 1858469794/<module>:5 - INFO - Start fetching article 118/812 - 34576548
# 18:14:35.029 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:14:36.251 - 1858469794/<module>:5 - INFO - Start fetching article 119/812 - 34500981
# 18:14:37.181 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:14:38.402 - 1858469794/<module>:5 - INFO - Start fetching article 120/812 - 34483264
# 18:14:39.377 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:14:39.380 - 1858469794/<module>:5 - INFO - Start fetching article 121/812 - 34443925
# 18:14:40.340 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:14:41.554 - 1858469794/<module>:5 - INFO - Start fetching article 122/812 - 34441354
# 18:14:42.512 - api/getCitingArticles:130 - INFO - Found: 5 siting articles. Fetching...
# 18:14:43.890 - 1858469794/<module>:5 - INFO - Start fetching article 123/812 - 34357777
# 18:14:44.811 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:14:46.012 - 1858469794/<module>:5 - INFO - Start fetching article 124/812 - 34323466
# 18:14:46.909 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:14:46.912 - 1858469794/<module>:5 - INFO - Start fetching article 125/812 - 34165866
# 18:14:47.788 - api/getCitingArticles:130 - INFO - Found: 8 siting articles. Fetching...
# 18:14:49.566 - 1858469794/<module>:5 - INFO - Start fetching article 126/812 - 34138547
# 18:14:50.575 - api/getCitingArticles:130 - INFO - Found: 8 siting articles. Fetching...
# 18:14:52.296 - 1858469794/<module>:5 - INFO - Start fetching article 127/812 - 33969854
# 18:14:53.442 - api/getCitingArticles:130 - INFO - Found: 11 siting articles. Fetching...
# 18:14:55.740 - 1858469794/<module>:5 - INFO - Start fetching article 128/812 - 33886276
# 18:14:58.770 - api/getCitingArticles:130 - INFO - Found: 8 siting articles. Fetching...
# 18:15:01.068 - 1858469794/<module>:5 - INFO - Start fetching article 129/812 - 33801512
# 18:15:03.127 - api/getCitingArticles:130 - INFO - Found: 14 siting articles. Fetching...
# 18:15:04.877 - 1858469794/<module>:5 - INFO - Start fetching article 130/812 - 33671802
# 18:15:07.983 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:15:09.381 - 1858469794/<module>:5 - INFO - Start fetching article 131/812 - 33501323
# 18:15:10.849 - api/getCitingArticles:130 - INFO - Found: 6 siting articles. Fetching...
# 18:15:12.206 - 1858469794/<module>:5 - INFO - Start fetching article 132/812 - 33496348
# 18:15:14.149 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:15:15.338 - 1858469794/<module>:5 - INFO - Start fetching article 133/812 - 33430089
# 18:15:16.248 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:15:17.321 - 1858469794/<module>:5 - INFO - Start fetching article 134/812 - 36733463
# 18:15:18.471 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:15:19.504 - 1858469794/<module>:5 - INFO - Start fetching article 135/812 - 33325722
# 18:15:20.626 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:15:21.580 - 1858469794/<module>:5 - INFO - Start fetching article 136/812 - 32806535
# 18:15:22.450 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:15:24.490 - 1858469794/<module>:5 - INFO - Start fetching article 137/812 - 35021724
# 18:15:25.431 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:15:26.495 - 1858469794/<module>:5 - INFO - Start fetching article 138/812 - 36132793
# 18:15:27.753 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:15:29.003 - 1858469794/<module>:5 - INFO - Start fetching article 139/812 - 32722350
# 18:15:30.203 - api/getCitingArticles:130 - INFO - Found: 6 siting articles. Fetching...
# 18:15:31.879 - 1858469794/<module>:5 - INFO - Start fetching article 140/812 - 32579650
# 18:15:32.768 - api/getCitingArticles:130 - INFO - Found: 5 siting articles. Fetching...
# 18:15:34.381 - 1858469794/<module>:5 - INFO - Start fetching article 141/812 - 32434157
# 18:15:35.326 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:15:36.879 - 1858469794/<module>:5 - INFO - Start fetching article 142/812 - 32318345
# 18:15:37.754 - api/getCitingArticles:130 - INFO - Found: 12 siting articles. Fetching...
# 18:15:42.835 - 1858469794/<module>:5 - INFO - Start fetching article 143/812 - 32316700
# 18:15:43.938 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:15:45.125 - 1858469794/<module>:5 - INFO - Start fetching article 144/812 - 32311172
# 18:15:45.992 - api/getCitingArticles:130 - INFO - Found: 33 siting articles. Fetching...
# 18:15:51.342 - 1858469794/<module>:5 - INFO - Start fetching article 145/812 - 32121969
# 18:15:52.837 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:15:54.049 - 1858469794/<module>:5 - INFO - Start fetching article 146/812 - 31756030
# 18:15:54.964 - api/getCitingArticles:130 - INFO - Found: 12 siting articles. Fetching...
# 18:15:56.884 - 1858469794/<module>:5 - INFO - Start fetching article 147/812 - 31703230
# 18:15:57.760 - api/getCitingArticles:130 - INFO - Found: 7 siting articles. Fetching...
# 18:15:59.763 - 1858469794/<module>:5 - INFO - Start fetching article 148/812 - 31657401
# 18:16:00.681 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:16:01.808 - 1858469794/<module>:5 - INFO - Start fetching article 149/812 - 31482557
# 18:16:02.768 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:16:04.280 - 1858469794/<module>:5 - INFO - Start fetching article 150/812 - 31414685
# 18:16:05.532 - api/getCitingArticles:130 - INFO - Found: 8 siting articles. Fetching...
# 18:16:07.124 - 1858469794/<module>:5 - INFO - Start fetching article 151/812 - 35515245
# 18:16:08.198 - api/getCitingArticles:130 - INFO - Found: 24 siting articles. Fetching...
# 18:16:10.495 - 1858469794/<module>:5 - INFO - Start fetching article 152/812 - 31025868
# 18:16:11.404 - api/getCitingArticles:130 - INFO - Found: 7 siting articles. Fetching...
# 18:16:12.915 - 1858469794/<module>:5 - INFO - Start fetching article 153/812 - 30916056
# 18:16:15.404 - api/getCitingArticles:130 - INFO - Found: 7 siting articles. Fetching...
# 18:16:17.057 - 1858469794/<module>:5 - INFO - Start fetching article 154/812 - 30821886
# 18:16:18.438 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:16:19.555 - 1858469794/<module>:5 - INFO - Start fetching article 155/812 - 30646687
# 18:16:20.691 - api/getCitingArticles:130 - INFO - Found: 9 siting articles. Fetching...
# 18:16:22.858 - 1858469794/<module>:5 - INFO - Start fetching article 156/812 - 30552609
# 18:16:24.249 - api/getCitingArticles:130 - INFO - Found: 31 siting articles. Fetching...
# 18:16:28.146 - 1858469794/<module>:5 - INFO - Start fetching article 157/812 - 30137113
# 18:16:29.206 - api/getCitingArticles:130 - INFO - Found: 7 siting articles. Fetching...
# 18:16:30.939 - 1858469794/<module>:5 - INFO - Start fetching article 158/812 - 30011881
# 18:16:32.241 - api/getCitingArticles:130 - INFO - Found: 7 siting articles. Fetching...
# 18:16:34.210 - 1858469794/<module>:5 - INFO - Start fetching article 159/812 - 29865158
# 18:16:35.194 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:16:36.535 - 1858469794/<module>:5 - INFO - Start fetching article 160/812 - 29561559
# 18:16:37.589 - api/getCitingArticles:130 - INFO - Found: 28 siting articles. Fetching...
# 18:16:40.278 - 1858469794/<module>:5 - INFO - Start fetching article 161/812 - 29375156
# 18:16:41.159 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:16:42.114 - 1858469794/<module>:5 - INFO - Start fetching article 162/812 - 29030573
# 18:16:43.026 - api/getCitingArticles:130 - INFO - Found: 12 siting articles. Fetching...
# 18:16:44.608 - 1858469794/<module>:5 - INFO - Start fetching article 163/812 - 28841187
# 18:16:45.784 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:16:47.002 - 1858469794/<module>:5 - INFO - Start fetching article 164/812 - 28487921
# 18:16:47.896 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:16:49.579 - 1858469794/<module>:5 - INFO - Start fetching article 165/812 - 28444919
# 18:16:50.481 - api/getCitingArticles:130 - INFO - Found: 8 siting articles. Fetching...
# 18:16:52.191 - 1858469794/<module>:5 - INFO - Start fetching article 166/812 - 28426069
# 18:16:53.138 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:16:54.493 - 1858469794/<module>:5 - INFO - Start fetching article 167/812 - 28384503
# 18:16:55.393 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:16:56.524 - 1858469794/<module>:5 - INFO - Start fetching article 168/812 - 28372426
# 18:16:57.667 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:16:57.670 - 1858469794/<module>:5 - INFO - Start fetching article 169/812 - 28319290
# 18:16:58.631 - api/getCitingArticles:130 - INFO - Found: 10 siting articles. Fetching...
# 18:17:00.531 - 1858469794/<module>:5 - INFO - Start fetching article 170/812 - 28282112
# 18:17:01.650 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:17:02.705 - 1858469794/<module>:5 - INFO - Start fetching article 171/812 - 28229137
# 18:17:03.703 - api/getCitingArticles:130 - INFO - Found: 13 siting articles. Fetching...
# 18:17:05.978 - 1858469794/<module>:5 - INFO - Start fetching article 172/812 - 28205515
# 18:17:06.983 - api/getCitingArticles:130 - INFO - Found: 26 siting articles. Fetching...
# 18:17:09.894 - 1858469794/<module>:5 - INFO - Start fetching article 173/812 - 28195418
# 18:17:10.809 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:17:11.936 - 1858469794/<module>:5 - INFO - Start fetching article 174/812 - 28191931
# 18:17:13.165 - api/getCitingArticles:130 - INFO - Found: 164 siting articles. Fetching...
# 18:17:17.499 - 1858469794/<module>:5 - INFO - Start fetching article 175/812 - 28122149
# 18:17:18.415 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:17:20.121 - 1858469794/<module>:5 - INFO - Start fetching article 176/812 - 28092122
# 18:17:21.280 - api/getCitingArticles:130 - INFO - Found: 16 siting articles. Fetching...
# 18:17:26.544 - 1858469794/<module>:5 - INFO - Start fetching article 177/812 - 28084408
# 18:17:27.460 - api/getCitingArticles:130 - INFO - Found: 9 siting articles. Fetching...
# 18:17:28.983 - 1858469794/<module>:5 - INFO - Start fetching article 178/812 - 28029740
# 18:17:31.180 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:17:32.717 - 1858469794/<module>:5 - INFO - Start fetching article 179/812 - 28010764
# 18:17:33.567 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:17:34.907 - 1858469794/<module>:5 - INFO - Start fetching article 180/812 - 32263450
# 18:17:35.961 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:17:37.046 - 1858469794/<module>:5 - INFO - Start fetching article 181/812 - 27673209
# 18:17:38.120 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:17:38.122 - 1858469794/<module>:5 - INFO - Start fetching article 182/812 - 27651318
# 18:17:39.185 - api/getCitingArticles:130 - INFO - Found: 11 siting articles. Fetching...
# 18:17:42.164 - 1858469794/<module>:5 - INFO - Start fetching article 183/812 - 27554174
# 18:17:43.159 - api/getCitingArticles:130 - INFO - Found: 6 siting articles. Fetching...
# 18:17:44.672 - 1858469794/<module>:5 - INFO - Start fetching article 184/812 - 27489980
# 18:17:46.358 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:17:49.014 - 1858469794/<module>:5 - INFO - Start fetching article 185/812 - 27404114
# 18:17:49.933 - api/getCitingArticles:130 - INFO - Found: 5 siting articles. Fetching...
# 18:17:52.107 - 1858469794/<module>:5 - INFO - Start fetching article 186/812 - 27381215
# 18:17:53.266 - api/getCitingArticles:130 - INFO - Found: 10 siting articles. Fetching...
# 18:17:55.243 - 1858469794/<module>:5 - INFO - Start fetching article 187/812 - 27273693
# 18:17:56.161 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:17:57.478 - 1858469794/<module>:5 - INFO - Start fetching article 188/812 - 27192268
# 18:17:58.389 - api/getCitingArticles:130 - INFO - Found: 33 siting articles. Fetching...
# 18:18:01.377 - 1858469794/<module>:5 - INFO - Start fetching article 189/812 - 27004738
# 18:18:04.962 - api/getCitingArticles:130 - INFO - Found: 22 siting articles. Fetching...
# 18:18:07.208 - 1858469794/<module>:5 - INFO - Start fetching article 190/812 - 26932059
# 18:18:08.084 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:18:08.086 - 1858469794/<module>:5 - INFO - Start fetching article 191/812 - 26925538
# 18:18:09.012 - api/getCitingArticles:130 - INFO - Found: 6 siting articles. Fetching...
# 18:18:10.330 - 1858469794/<module>:5 - INFO - Start fetching article 192/812 - 26753543
# 18:18:11.222 - api/getCitingArticles:130 - INFO - Found: 9 siting articles. Fetching...
# 18:18:13.227 - 1858469794/<module>:5 - INFO - Start fetching article 193/812 - 26745990
# 18:18:14.131 - api/getCitingArticles:130 - INFO - Found: 5 siting articles. Fetching...
# 18:18:15.922 - 1858469794/<module>:5 - INFO - Start fetching article 194/812 - 26555960
# 18:18:17.182 - api/getCitingArticles:130 - INFO - Found: 8 siting articles. Fetching...
# 18:18:18.753 - 1858469794/<module>:5 - INFO - Start fetching article 195/812 - 26549694
# 18:18:19.641 - api/getCitingArticles:130 - INFO - Found: 12 siting articles. Fetching...
# 18:18:21.898 - 1858469794/<module>:5 - INFO - Start fetching article 196/812 - 26485929
# 18:18:22.785 - api/getCitingArticles:130 - INFO - Found: 11 siting articles. Fetching...
# 18:18:24.691 - 1858469794/<module>:5 - INFO - Start fetching article 197/812 - 26467473
# 18:18:25.609 - api/getCitingArticles:130 - INFO - Found: 6 siting articles. Fetching...
# 18:18:27.500 - 1858469794/<module>:5 - INFO - Start fetching article 198/812 - 26334136
# 18:18:28.900 - api/getCitingArticles:130 - INFO - Found: 9 siting articles. Fetching...
# 18:18:30.400 - 1858469794/<module>:5 - INFO - Start fetching article 199/812 - 26329185
# 18:18:31.274 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:18:32.467 - 1858469794/<module>:5 - INFO - Start fetching article 200/812 - 26174920
# 18:18:33.356 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:18:34.648 - 1858469794/<module>:5 - INFO - Start fetching article 201/812 - 25821705
# 18:18:35.535 - api/getCitingArticles:130 - INFO - Found: 15 siting articles. Fetching...
# 18:18:37.403 - 1858469794/<module>:5 - INFO - Start fetching article 202/812 - 25680787
# 18:18:39.797 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:18:41.203 - 1858469794/<module>:5 - INFO - Start fetching article 203/812 - 25343348
# 18:18:42.331 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:18:43.588 - 1858469794/<module>:5 - INFO - Start fetching article 204/812 - 25271711
# 18:18:44.468 - api/getCitingArticles:130 - INFO - Found: 14 siting articles. Fetching...
# 18:18:46.484 - 1858469794/<module>:5 - INFO - Start fetching article 205/812 - 25247135
# 18:18:47.737 - api/getCitingArticles:130 - INFO - Found: 20 siting articles. Fetching...
# 18:18:49.547 - 1858469794/<module>:5 - INFO - Start fetching article 206/812 - 25226205
# 18:18:50.385 - api/getCitingArticles:130 - INFO - Found: 11 siting articles. Fetching...
# 18:18:52.305 - 1858469794/<module>:5 - INFO - Start fetching article 207/812 - 24991505
# 18:18:53.227 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:18:54.693 - 1858469794/<module>:5 - INFO - Start fetching article 208/812 - 24759541
# 18:18:56.770 - api/getCitingArticles:130 - INFO - Found: 66 siting articles. Fetching...
# 18:19:05.234 - 1858469794/<module>:5 - INFO - Start fetching article 209/812 - 24755991
# 18:19:06.155 - api/getCitingArticles:130 - INFO - Found: 16 siting articles. Fetching...
# 18:19:08.171 - 1858469794/<module>:5 - INFO - Start fetching article 210/812 - 24720469
# 18:19:09.319 - api/getCitingArticles:130 - INFO - Found: 26 siting articles. Fetching...
# 18:19:11.369 - 1858469794/<module>:5 - INFO - Start fetching article 211/812 - 24593606
# 18:19:12.276 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:19:12.279 - 1858469794/<module>:5 - INFO - Start fetching article 212/812 - 24289310
# 18:19:13.240 - api/getCitingArticles:130 - INFO - Found: 19 siting articles. Fetching...
# 18:19:17.913 - 1858469794/<module>:5 - INFO - Start fetching article 213/812 - 24171189
# 18:19:18.832 - api/getCitingArticles:130 - INFO - Found: 35 siting articles. Fetching...
# 18:19:21.745 - 1858469794/<module>:5 - INFO - Start fetching article 214/812 - 23852964
# 18:19:22.675 - api/getCitingArticles:130 - INFO - Found: 6 siting articles. Fetching...
# 18:19:24.353 - 1858469794/<module>:5 - INFO - Start fetching article 215/812 - 23308190
# 18:19:25.465 - api/getCitingArticles:130 - INFO - Found: 8 siting articles. Fetching...
# 18:19:27.547 - 1858469794/<module>:5 - INFO - Start fetching article 216/812 - 23247630
# 18:19:28.540 - api/getCitingArticles:130 - INFO - Found: 6 siting articles. Fetching...
# 18:19:30.031 - 1858469794/<module>:5 - INFO - Start fetching article 217/812 - 23236461
# 18:19:30.932 - api/getCitingArticles:130 - INFO - Found: 11 siting articles. Fetching...
# 18:19:32.440 - 1858469794/<module>:5 - INFO - Start fetching article 218/812 - 23198287
# 18:19:33.373 - api/getCitingArticles:130 - INFO - Found: 12 siting articles. Fetching...
# 18:19:35.045 - 1858469794/<module>:5 - INFO - Start fetching article 219/812 - 23183423
# 18:19:35.971 - api/getCitingArticles:130 - INFO - Found: 17 siting articles. Fetching...
# 18:19:38.389 - 1858469794/<module>:5 - INFO - Start fetching article 220/812 - 23148085
# 18:19:39.283 - api/getCitingArticles:130 - INFO - Found: 9 siting articles. Fetching...
# 18:19:43.483 - 1858469794/<module>:5 - INFO - Start fetching article 221/812 - 23138867
# 18:19:44.474 - api/getCitingArticles:130 - INFO - Found: 23 siting articles. Fetching...
# 18:19:47.806 - 1858469794/<module>:5 - INFO - Start fetching article 222/812 - 23132176
# 18:19:49.762 - api/getCitingArticles:130 - INFO - Found: 29 siting articles. Fetching...
# 18:19:55.911 - 1858469794/<module>:5 - INFO - Start fetching article 223/812 - 22827393
# 18:19:56.858 - api/getCitingArticles:130 - INFO - Found: 6 siting articles. Fetching...
# 18:19:58.668 - 1858469794/<module>:5 - INFO - Start fetching article 224/812 - 22834824
# 18:19:59.650 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:20:01.394 - 1858469794/<module>:5 - INFO - Start fetching article 225/812 - 22706626
# 18:20:02.506 - api/getCitingArticles:130 - INFO - Found: 12 siting articles. Fetching...
# 18:20:04.121 - 1858469794/<module>:5 - INFO - Start fetching article 226/812 - 22475043
# 18:20:05.195 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:20:06.222 - 1858469794/<module>:5 - INFO - Start fetching article 227/812 - 22448125
# 18:20:07.206 - api/getCitingArticles:130 - INFO - Found: 26 siting articles. Fetching...
# 18:20:10.292 - 1858469794/<module>:5 - INFO - Start fetching article 228/812 - 22417054
# 18:20:11.144 - api/getCitingArticles:130 - INFO - Found: 8 siting articles. Fetching...
# 18:20:12.780 - 1858469794/<module>:5 - INFO - Start fetching article 229/812 - 22252263
# 18:20:13.756 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:20:14.878 - 1858469794/<module>:5 - INFO - Start fetching article 230/812 - 22101718
# 18:20:15.807 - api/getCitingArticles:130 - INFO - Found: 18 siting articles. Fetching...
# 18:20:18.353 - 1858469794/<module>:5 - INFO - Start fetching article 231/812 - 22014272
# 18:20:19.221 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:20:23.417 - 1858469794/<module>:5 - INFO - Start fetching article 232/812 - 21854460
# 18:20:24.258 - api/getCitingArticles:130 - INFO - Found: 9 siting articles. Fetching...
# 18:20:25.942 - 1858469794/<module>:5 - INFO - Start fetching article 233/812 - 21645564
# 18:20:26.876 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:20:28.253 - 1858469794/<module>:5 - INFO - Start fetching article 234/812 - 21346297
# 18:20:29.323 - api/getCitingArticles:130 - INFO - Found: 10 siting articles. Fetching...
# 18:20:32.089 - 1858469794/<module>:5 - INFO - Start fetching article 235/812 - 21312225
# 18:20:33.027 - api/getCitingArticles:130 - INFO - Found: 5 siting articles. Fetching...
# 18:20:34.527 - 1858469794/<module>:5 - INFO - Start fetching article 236/812 - 21298127
# 18:20:35.462 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:20:36.547 - 1858469794/<module>:5 - INFO - Start fetching article 237/812 - 21286815
# 18:20:37.403 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:20:38.513 - 1858469794/<module>:5 - INFO - Start fetching article 238/812 - 20731831
# 18:20:39.399 - api/getCitingArticles:130 - INFO - Found: 11 siting articles. Fetching...
# 18:20:41.420 - 1858469794/<module>:5 - INFO - Start fetching article 239/812 - 20615017
# 18:20:43.924 - api/getCitingArticles:130 - INFO - Found: 22 siting articles. Fetching...
# 18:20:46.886 - 1858469794/<module>:5 - INFO - Start fetching article 240/812 - 20394393
# 18:20:47.906 - api/getCitingArticles:130 - INFO - Found: 9 siting articles. Fetching...
# 18:20:49.503 - 1858469794/<module>:5 - INFO - Start fetching article 241/812 - 20104575
# 18:20:50.832 - api/getCitingArticles:130 - INFO - Found: 28 siting articles. Fetching...
# 18:20:53.229 - 1858469794/<module>:5 - INFO - Start fetching article 242/812 - 19946462
# 18:20:54.208 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:20:55.322 - 1858469794/<module>:5 - INFO - Start fetching article 243/812 - 19852831
# 18:20:56.348 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:20:57.480 - 1858469794/<module>:5 - INFO - Start fetching article 244/812 - 19801779
# 18:20:58.372 - api/getCitingArticles:130 - INFO - Found: 7 siting articles. Fetching...
# 18:21:00.051 - 1858469794/<module>:5 - INFO - Start fetching article 245/812 - 19793239
# 18:21:00.891 - api/getCitingArticles:130 - INFO - Found: 6 siting articles. Fetching...
# 18:21:02.255 - 1858469794/<module>:5 - INFO - Start fetching article 246/812 - 19133434
# 18:21:03.107 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:21:03.108 - 1858469794/<module>:5 - INFO - Start fetching article 247/812 - 25364310
# 18:21:03.977 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:21:05.210 - 1858469794/<module>:5 - INFO - Start fetching article 248/812 - 16827627
# 18:21:06.181 - api/getCitingArticles:130 - INFO - Found: 33 siting articles. Fetching...
# 18:21:10.999 - 1858469794/<module>:5 - INFO - Start fetching article 249/812 - 16776814
# 18:21:11.856 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:21:13.458 - 1858469794/<module>:5 - INFO - Start fetching article 250/812 - 15766802
# 18:21:14.340 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:21:15.784 - 1858469794/<module>:5 - INFO - Start fetching article 251/812 - 15127327
# 18:21:16.698 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:21:19.962 - 1858469794/<module>:5 - INFO - Start fetching article 252/812 - 15004429
# 18:21:21.039 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:21:22.311 - 1858469794/<module>:5 - INFO - Start fetching article 253/812 - 14998652
# 18:21:23.160 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:21:23.163 - 1858469794/<module>:5 - INFO - Start fetching article 254/812 - 14998651
# 18:21:24.183 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:21:24.186 - 1858469794/<module>:5 - INFO - Start fetching article 255/812 - 12535582
# 18:21:25.090 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:21:25.091 - 1858469794/<module>:5 - INFO - Start fetching article 256/812 - 11905150
# 18:21:26.104 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:21:27.341 - 1858469794/<module>:5 - INFO - Start fetching article 257/812 - 11812629
# 18:21:28.676 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:21:29.821 - 1858469794/<module>:5 - INFO - Start fetching article 258/812 - 11409301
# 18:21:30.773 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:21:31.778 - 1858469794/<module>:5 - INFO - Start fetching article 259/812 - 10371119
# 18:21:32.702 - api/getCitingArticles:130 - INFO - Found: 13 siting articles. Fetching...
# 18:21:34.683 - 1858469794/<module>:5 - INFO - Start fetching article 260/812 - 9986923
# 18:21:35.698 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:21:36.675 - 1858469794/<module>:5 - INFO - Start fetching article 261/812 - 9628377
# 18:21:37.755 - api/getCitingArticles:130 - INFO - Found: 11 siting articles. Fetching...
# 18:21:39.073 - 1858469794/<module>:5 - INFO - Start fetching article 262/812 - 9592946
# 18:21:40.051 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:21:41.154 - 1858469794/<module>:5 - INFO - Start fetching article 263/812 - 9387855
# 18:21:43.106 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:21:43.109 - 1858469794/<module>:5 - INFO - Start fetching article 264/812 - 9444780
# 18:21:44.028 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:22:06.256 - 1858469794/<module>:5 - INFO - Start fetching article 265/812 - 8917905
# 18:22:07.260 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:22:08.456 - 1858469794/<module>:5 - INFO - Start fetching article 266/812 - 7540332
# 18:22:09.497 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:22:09.497 - 1858469794/<module>:5 - INFO - Start fetching article 267/812 - 39057890
# 18:22:10.446 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:22:10.449 - 1858469794/<module>:5 - INFO - Start fetching article 268/812 - 38392738
# 18:22:11.515 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:22:14.840 - 1858469794/<module>:5 - INFO - Start fetching article 269/812 - 37570524
# 18:22:16.105 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:22:20.402 - 1858469794/<module>:5 - INFO - Start fetching article 270/812 - 36079307
# 18:22:21.269 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:22:22.415 - 1858469794/<module>:5 - INFO - Start fetching article 271/812 - 32872209
# ...
# 18:40:59.363 - 1858469794/<module>:5 - INFO - Start fetching article 708/812 - 35463105
# 18:41:00.590 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:41:00.593 - 1858469794/<module>:5 - INFO - Start fetching article 709/812 - 35172832
# 18:41:01.613 - api/getCitingArticles:130 - INFO - Found: 11 siting articles. Fetching...
# 18:41:03.383 - 1858469794/<module>:5 - INFO - Start fetching article 710/812 - 34981317
# 18:41:04.274 - api/getCitingArticles:130 - INFO - Found: 7 siting articles. Fetching...
# 18:41:06.017 - 1858469794/<module>:5 - INFO - Start fetching article 711/812 - 34967606
# 18:41:06.933 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:41:10.580 - 1858469794/<module>:5 - INFO - Start fetching article 712/812 - 34953414
# 18:41:11.642 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:41:11.646 - 1858469794/<module>:5 - INFO - Start fetching article 713/812 - 34514024
# 18:41:13.086 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:41:14.128 - 1858469794/<module>:5 - INFO - Start fetching article 714/812 - 34353349
# 18:41:15.127 - api/getCitingArticles:130 - INFO - Found: 12 siting articles. Fetching...
# 18:41:17.000 - 1858469794/<module>:5 - INFO - Start fetching article 715/812 - 34296617
# 18:41:18.429 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:41:20.335 - 1858469794/<module>:5 - INFO - Start fetching article 716/812 - 34281263
# 18:41:21.203 - api/getCitingArticles:130 - INFO - Found: 6 siting articles. Fetching...
# 18:41:22.984 - 1858469794/<module>:5 - INFO - Start fetching article 717/812 - 37181111
# 18:41:23.816 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:41:24.945 - 1858469794/<module>:5 - INFO - Start fetching article 718/812 - 34064994
# 18:41:25.904 - api/getCitingArticles:130 - INFO - Found: 11 siting articles. Fetching...
# 18:41:27.990 - 1858469794/<module>:5 - INFO - Start fetching article 719/812 - 34020687
# 18:41:28.962 - api/getCitingArticles:130 - INFO - Found: 11 siting articles. Fetching...
# 18:41:31.422 - 1858469794/<module>:5 - INFO - Start fetching article 720/812 - 33992679
# 18:41:32.429 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:41:34.000 - 1858469794/<module>:5 - INFO - Start fetching article 721/812 - 33857477
# 18:41:34.828 - api/getCitingArticles:130 - INFO - Found: 5 siting articles. Fetching...
# 18:41:36.277 - 1858469794/<module>:5 - INFO - Start fetching article 722/812 - 33718662
# 18:41:37.502 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:41:39.323 - 1858469794/<module>:5 - INFO - Start fetching article 723/812 - 33613055
# 18:41:40.244 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:41:40.247 - 1858469794/<module>:5 - INFO - Start fetching article 724/812 - 33529737
# 18:41:41.161 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:41:42.704 - 1858469794/<module>:5 - INFO - Start fetching article 725/812 - 33467541
# 18:41:44.277 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:41:45.579 - 1858469794/<module>:5 - INFO - Start fetching article 726/812 - 33158205
# 18:41:46.885 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:41:46.888 - 1858469794/<module>:5 - INFO - Start fetching article 727/812 - 33132322
# 18:41:48.601 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:41:49.786 - 1858469794/<module>:5 - INFO - Start fetching article 728/812 - 33113360
# 18:41:51.293 - api/getCitingArticles:130 - INFO - Found: 5 siting articles. Fetching...
# 18:41:52.766 - 1858469794/<module>:5 - INFO - Start fetching article 729/812 - 33108087
# 18:41:54.677 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:41:56.690 - 1858469794/<module>:5 - INFO - Start fetching article 730/812 - 32817324
# 18:41:57.729 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:41:59.171 - 1858469794/<module>:5 - INFO - Start fetching article 731/812 - 32688247
# 18:42:00.285 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:42:01.412 - 1858469794/<module>:5 - INFO - Start fetching article 732/812 - 32599766
# 18:42:02.440 - api/getCitingArticles:130 - INFO - Found: 6 siting articles. Fetching...
# 18:42:04.213 - 1858469794/<module>:5 - INFO - Start fetching article 733/812 - 32305682
# 18:42:06.444 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:42:07.447 - 1858469794/<module>:5 - INFO - Start fetching article 734/812 - 32298973
# 18:42:08.417 - api/getCitingArticles:130 - INFO - Found: 6 siting articles. Fetching...
# 18:42:10.268 - 1858469794/<module>:5 - INFO - Start fetching article 735/812 - 32188126
# 18:42:11.154 - api/getCitingArticles:130 - INFO - Found: 13 siting articles. Fetching...
# 18:42:13.033 - 1858469794/<module>:5 - INFO - Start fetching article 736/812 - 32179709
# 18:42:13.912 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:42:15.067 - 1858469794/<module>:5 - INFO - Start fetching article 737/812 - 32101051
# 18:42:16.009 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:42:17.544 - 1858469794/<module>:5 - INFO - Start fetching article 738/812 - 31327020
# 18:42:18.636 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:42:20.226 - 1858469794/<module>:5 - INFO - Start fetching article 739/812 - 31249784
# 18:42:21.133 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:42:22.617 - 1858469794/<module>:5 - INFO - Start fetching article 740/812 - 31167088
# 18:42:23.841 - api/getCitingArticles:130 - INFO - Found: 5 siting articles. Fetching...
# 18:42:25.501 - 1858469794/<module>:5 - INFO - Start fetching article 741/812 - 31124759
# 18:42:26.387 - api/getCitingArticles:130 - INFO - Found: 10 siting articles. Fetching...
# 18:42:28.267 - 1858469794/<module>:5 - INFO - Start fetching article 742/812 - 31113613
# 18:42:29.474 - api/getCitingArticles:130 - INFO - Found: 8 siting articles. Fetching...
# 18:42:31.990 - 1858469794/<module>:5 - INFO - Start fetching article 743/812 - 31054964
# 18:42:32.951 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:42:32.954 - 1858469794/<module>:5 - INFO - Start fetching article 744/812 - 30955655
# 18:42:35.106 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:42:36.444 - 1858469794/<module>:5 - INFO - Start fetching article 745/812 - 30821472
# 18:42:38.280 - api/getCitingArticles:130 - INFO - Found: 5 siting articles. Fetching...
# 18:42:39.486 - 1858469794/<module>:5 - INFO - Start fetching article 746/812 - 30770487
# 18:42:41.307 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:42:42.503 - 1858469794/<module>:5 - INFO - Start fetching article 747/812 - 30689104
# 18:42:43.573 - api/getCitingArticles:130 - INFO - Found: 16 siting articles. Fetching...
# 18:42:45.507 - 1858469794/<module>:5 - INFO - Start fetching article 748/812 - 30684275
# 18:42:46.475 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:42:47.957 - 1858469794/<module>:5 - INFO - Start fetching article 749/812 - 30639734
# 18:42:49.168 - api/getCitingArticles:130 - INFO - Found: 16 siting articles. Fetching...
# 18:42:51.782 - 1858469794/<module>:5 - INFO - Start fetching article 750/812 - 30336182
# 18:42:52.737 - api/getCitingArticles:130 - INFO - Found: 13 siting articles. Fetching...
# 18:42:54.432 - 1858469794/<module>:5 - INFO - Start fetching article 751/812 - 30286343
# 18:42:55.306 - api/getCitingArticles:130 - INFO - Found: 0 siting articles. Fetching...
# 18:42:55.309 - 1858469794/<module>:5 - INFO - Start fetching article 752/812 - 30084066
# 18:42:56.178 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:42:57.169 - 1858469794/<module>:5 - INFO - Start fetching article 753/812 - 29941849
# 18:42:58.850 - api/getCitingArticles:130 - INFO - Found: 3 siting articles. Fetching...
# 18:43:00.416 - 1858469794/<module>:5 - INFO - Start fetching article 754/812 - 29685804
# 18:43:01.387 - api/getCitingArticles:130 - INFO - Found: 9 siting articles. Fetching...
# 18:43:03.102 - 1858469794/<module>:5 - INFO - Start fetching article 755/812 - 29621136
# 18:43:04.079 - api/getCitingArticles:130 - INFO - Found: 8 siting articles. Fetching...
# 18:43:05.852 - 1858469794/<module>:5 - INFO - Start fetching article 756/812 - 29620430
# 18:43:06.846 - api/getCitingArticles:130 - INFO - Found: 6 siting articles. Fetching...
# 18:43:08.641 - 1858469794/<module>:5 - INFO - Start fetching article 757/812 - 29500267
# 18:43:10.733 - api/getCitingArticles:130 - INFO - Found: 11 siting articles. Fetching...
# 18:43:13.167 - 1858469794/<module>:5 - INFO - Start fetching article 758/812 - 29374543
# 18:43:14.318 - api/getCitingArticles:130 - INFO - Found: 11 siting articles. Fetching...
# 18:43:17.013 - 1858469794/<module>:5 - INFO - Start fetching article 759/812 - 29264366
# 18:43:17.902 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:43:19.682 - 1858469794/<module>:5 - INFO - Start fetching article 760/812 - 29258200
# 18:43:20.673 - api/getCitingArticles:130 - INFO - Found: 7 siting articles. Fetching...
# 18:43:23.483 - 1858469794/<module>:5 - INFO - Start fetching article 761/812 - 29152461
# 18:43:24.385 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:43:25.718 - 1858469794/<module>:5 - INFO - Start fetching article 762/812 - 29039090
# 18:43:26.813 - api/getCitingArticles:130 - INFO - Found: 6 siting articles. Fetching...
# 18:43:28.398 - 1858469794/<module>:5 - INFO - Start fetching article 763/812 - 29033055
# 18:43:29.373 - api/getCitingArticles:130 - INFO - Found: 9 siting articles. Fetching...
# 18:43:31.777 - 1858469794/<module>:5 - INFO - Start fetching article 764/812 - 28733334
# 18:43:32.904 - api/getCitingArticles:130 - INFO - Found: 6 siting articles. Fetching...
# 18:43:34.430 - 1858469794/<module>:5 - INFO - Start fetching article 765/812 - 28706390
# 18:43:35.517 - api/getCitingArticles:130 - INFO - Found: 7 siting articles. Fetching...
# 18:43:37.294 - 1858469794/<module>:5 - INFO - Start fetching article 766/812 - 28612634
# 18:43:38.188 - api/getCitingArticles:130 - INFO - Found: 4 siting articles. Fetching...
# 18:43:39.736 - 1858469794/<module>:5 - INFO - Start fetching article 767/812 - 28485474
# 18:43:40.771 - api/getCitingArticles:130 - INFO - Found: 14 siting articles. Fetching...
# 18:43:47.297 - 1858469794/<module>:5 - INFO - Start fetching article 768/812 - 28409861
# 18:43:48.503 - api/getCitingArticles:130 - INFO - Found: 9 siting articles. Fetching...
# 18:43:50.426 - 1858469794/<module>:5 - INFO - Start fetching article 769/812 - 28402950
# 18:43:51.346 - api/getCitingArticles:130 - INFO - Found: 26 siting articles. Fetching...
# 18:43:54.397 - 1858469794/<module>:5 - INFO - Start fetching article 770/812 - 28220406
# 18:43:55.686 - api/getCitingArticles:130 - INFO - Found: 5 siting articles. Fetching...
# 18:43:57.390 - 1858469794/<module>:5 - INFO - Start fetching article 771/812 - 27799810
# 18:43:58.516 - api/getCitingArticles:130 - INFO - Found: 10 siting articles. Fetching...
# 18:44:00.100 - 1858469794/<module>:5 - INFO - Start fetching article 772/812 - 27771107
# 18:44:01.117 - api/getCitingArticles:130 - INFO - Found: 1 siting articles. Fetching...
# 18:44:02.413 - 1858469794/<module>:5 - INFO - Start fetching article 773/812 - 27614734
# 18:44:03.267 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:44:04.773 - 1858469794/<module>:5 - INFO - Start fetching article 774/812 - 27604457
# 18:44:05.936 - api/getCitingArticles:130 - INFO - Found: 24 siting articles. Fetching...
# 18:44:08.139 - 1858469794/<module>:5 - INFO - Start fetching article 775/812 - 27464990
# 18:44:09.244 - api/getCitingArticles:130 - INFO - Found: 21 siting articles. Fetching...
# 18:44:11.590 - 1858469794/<module>:5 - INFO - Start fetching article 776/812 - 27423329
# 18:44:12.815 - api/getCitingArticles:130 - INFO - Found: 12 siting articles. Fetching...
# 18:44:17.246 - 1858469794/<module>:5 - INFO - Start fetching article 777/812 - 27392817
# 18:44:18.332 - api/getCitingArticles:130 - INFO - Found: 8 siting articles. Fetching...
# 18:44:20.186 - 1858469794/<module>:5 - INFO - Start fetching article 778/812 - 27357227
# 18:44:21.066 - api/getCitingArticles:130 - INFO - Found: 10 siting articles. Fetching...
# 18:44:23.196 - 1858469794/<module>:5 - INFO - Start fetching article 779/812 - 27261765
# 18:44:24.257 - api/getCitingArticles:130 - INFO - Found: 2 siting articles. Fetching...
# 18:44:26.376 - 1858469794/<module>:5 - INFO - Start fetching article 780/812 - 27190158
# 18:44:27.230 - api/getCitingArticles:130 - INFO - Found: 6 siting articles. Fetching...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 7
#       5     logging.info(f'Start fetching article {i+1}/{tot_articles} - {pmid}')
#       6     articles = pubmed.getCitingArticles(pmid)
# ----> 7     dict_articles = [x.toDict() for x in articles]
#       8     citing = pd.concat([citing, pd.DataFrame(dict_articles)], ignore_index=True)
#      10 # Drop duplicates
#
# File ~/dev/study/ablation_db/pymedx_custom/api.py:140, in PubMed.getCitingArticles(self, pmid, doi, max_results)
#     138 # Get the articles themselves
#     139 for batch in batches(citing_article_ids, 250):
# --> 140     yield from self._getArticles(article_ids=batch)
#
# File ~/dev/study/ablation_db/pymedx_custom/api.py:393, in PubMed._getArticles(self, article_ids)
#     391 for article in root.iterchildren():
#     392     if article.tag == "PubmedArticle":
# --> 393         yield PubMedArticle(xml_element=article)
#     394     else:
#     395         unknown_article_counter += 1
#
# File ~/dev/study/ablation_db/pymedx_custom/article.py:52, in PubMedArticle.__init__(self, xml_element, *args, **kwargs)
#      50 # If an XML element is provided, use it for initialization
#      51 if xml_element is not None:
# ---> 52     self._initializeFromXML(xml_element=xml_element)
#      54 # If no XML element was provided, try to parse the input parameters
#      55 else:
#      56     for field in self.__slots__:
#
# File ~/dev/study/ablation_db/pymedx_custom/article.py:75, in PubMedArticle._initializeFromXML(self, xml_element)
#      73 self.type = getAllContent(element=self.xml, path=base + 'PublicationTypeList/PublicationType')
#      74 self.authors = self._extractAuthors(base)
# ---> 75 self.publication_date = self._extractPublicationDate(base)
#      77 # Pubmed data
#      78 base = 'PubmedData/'
#
# File ~/dev/study/ablation_db/pymedx_custom/article.py:149, in PubMedArticle._extractPublicationDate(self, base)
#     145             return None
#     147     date_str = '/'.join([publication_year, publication_month, publication_day])
# --> 149     return datetime.datetime.strptime(date_str, "%Y/%b/%d")
#     150 return None
#
# File /usr/lib/python3.13/_strptime.py:674, in _strptime_datetime(cls, data_string, format)
#     671 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     672     """Return a class cls instance based on the input string and the
#     673     format string."""
# --> 674     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     675     tzname, gmtoff = tt[-2:]
#     676     args = tt[:6] + (fraction,)
#
# File /usr/lib/python3.13/_strptime.py:453, in _strptime(data_string, format)
#     451 found = format_regex.match(data_string)
#     452 if not found:
# --> 453     raise ValueError("time data %r does not match format %r" %
#     454                      (data_string, format))
#     455 if len(data_string) != found.end():
#     456     raise ValueError("unconverted data remains: %s" %
#     457                       data_string[found.end():])
#
# ValueError: time data '2021/Sept/15' does not match format '%Y/%b/%d'

# %% [markdown]
# ## Step 3
# Get references, which are cited in articles of base list

# %%
refs = pd.DataFrame(columns=base.columns)

tot_articles = len(base)
for i, ref_list in enumerate(base['references'].dropna()):
    logging.info(f'Start fetching refernces for article {i+1}/{tot_articles} - {ref_list}')
    if ref_list:
        ref_list = eval(ref_list)
        ids = [ref['pmid'] for ref in ref_list if ref['pmid'] is not None]
        logging.info(f'Fetching {len(ids)} references...')
        articles = list(pubmed.getArticles(ids))
        logging.info(f'Fetched {len(articles)} references')
        dict_articles = [x.to_dict() for x in articles]
        refs = pd.concat([refs, pd.DataFrame(dict_articles)], ignore_index=True)

# Drop duplicates
refs.drop_duplicates(subset='doi', inplace=True)

# Drop articles already in the base
refs = refs[~refs.doi.isin(base.doi)]

# %% [markdown]
# ## Step 4
# Combine all lists

# %%
all_articles = pd.concat([base, citing, refs], ignore_index=True)
all_articles.drop_duplicates(subset='doi', inplace=True)
all_articles = all_articles[all_articles['publication_date'] > '1993-01-01']
all_articles.to_csv('all_articles.csv', index=False)

# %% [markdown]
# ## Some
# Get authors statistics

# %%
from collections import Counter

authors = []
for authorlist in all_articles['authors']:
    authorlist = eval(authorlist)
    authors.extend([x['lastname'].lower() for x in authorlist if x['lastname'] is not None])

auth_counter = Counter(authors)
auth_counter.most_common(10)
# Out:
# [('wang', 774),
#  ('zhang', 606),
#  ('li', 597),
#  ('liu', 517),
#  ('chen', 437),
#  ('yang', 311),
#  ('kim', 296),
#  ('lee', 235),
#  ('wu', 223),
#  ('huang', 204)]

# %% [markdown]
# Get statistics on keywords

# %%
from collections import Counter

kw = Counter()
for kwlist in all_articles['keywords'].dropna():
    kwlist = eval(kwlist)
    kw.update([kw.lower() for kw in kwlist if kw is not None])
kw.most_common(20)
# Out:
# [('nanoparticles', 323),
#  ('gold nanoparticles', 161),
#  ('silver nanoparticles', 148),
#  ('laser ablation', 136),
#  ('drug delivery', 92),
#  ('nanomedicine', 71),
#  ('cytotoxicity', 67),
#  ('nanotechnology', 67),
#  ('surface plasmon resonance', 65),
#  ('cancer', 62),
#  ('toxicity', 60),
#  ('nanomaterials', 59),
#  ('plasmonics', 54),
#  ('photothermal therapy', 51),
#  ('antibacterial activity', 51),
#  ('sers', 49),
#  ('antibacterial', 46),
#  ('oxidative stress', 46),
#  ('wound healing', 46),
#  ('green synthesis', 45)]
